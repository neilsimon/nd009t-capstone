# %%
import os
import boto3
import io
import sagemaker

import pandas as pd
import numpy as np

from sagemaker import KMeans

# %%
role = sagemaker.get_execution_role()
s3_client = boto3.client("s3")
s3Bucket = "sagemaker-studio-p0xlvix7lda"

# %%
source_data = "s3://sagemaker-studio-p0xlvix7lda/Gold daily processed final.csv"
response = s3_client.get_object(Bucket=s3Bucket, Key="Gold daily processed final.csv")
response_body = response["Body"].read()
table = pd.read_csv(io.BytesIO(response_body), header=0, delimiter=",", low_memory=False, parse_dates=['Date'], index_col=0)
table.head()
# Out:
#             Gold Price      S&P  Gold Return  Gold Return 2 day back 1  \
# Date
# 2006-01-26       559.7  1273.83    -0.004447                  0.006985
# 2006-01-27       558.7  1283.72    -0.001787                  0.003586
# 2006-01-30       565.8  1285.19     0.012708                 -0.006226
# 2006-01-31       570.8  1280.08     0.008837                  0.010899
# 2006-02-01       569.4  1282.46    -0.002453                  0.021657
#
#             Gold Return 4 day back 3  Gold Return 8 day back 7  Var 16 day  \
# Date
# 2006-01-26                  0.008854                  0.036524    0.013745
# 2006-01-27                  0.025749                  0.033061    0.013338
# 2006-01-30                  0.006805                  0.034649    0.012713
# 2006-01-31                  0.011201                  0.008013    0.011519
# 2006-02-01                  0.000716                  0.025721    0.010985
#
#             Normalised Gold Return  Normalised Gold Return 2 day back 1  \
# Date
# 2006-01-26               -0.323525                             0.359369
# 2006-01-27               -0.133952                             0.190116
# 2006-01-30                0.999577                            -0.346257
# 2006-01-31                0.767178                             0.669035
# 2006-02-01               -0.223273                             1.394069
#
#             Normalised Gold Return 4 day back 3  ...  S&P Return 8 day back 7  \
# Date                                             ...
# 2006-01-26                             0.322096  ...                 0.007515
# 2006-01-27                             0.965259  ...                 0.003494
# 2006-01-30                             0.267636  ...                -0.000319
# 2006-01-31                             0.486221  ...                -0.022214
# 2006-02-01                             0.032610  ...                -0.020059
#
#             Var 16 day.1  Normalised S&P Return  \
# Date
# 2006-01-26      0.006625               1.092031
# 2006-01-27      0.006686               1.161302
# 2006-01-30      0.006686               0.171274
# 2006-01-31      0.006339              -0.627284
# 2006-02-01      0.006281               0.296037
#
#             Normalised S&P Return 2 day back 1  \
# Date
# 2006-01-26                            0.072626
# 2006-01-27                            0.581902
# 2006-01-30                            1.592265
# 2006-01-31                            0.994861
# 2006-02-01                           -0.319243
#
#             Normalised S&P Return 4 day back 3  \
# Date
# 2006-01-26                           -1.129939
# 2006-01-27                           -0.647845
# 2006-01-30                           -1.184882
# 2006-01-31                            0.771635
# 2006-02-01                            1.253555
#
#             Normalised S&P Return 8 day back 7  Tomorrow Gold  Tomorrow S&P  \
# Date
# 2006-01-26                            0.401029          558.7       1283.72
# 2006-01-27                            0.184792          565.8       1285.19
# 2006-01-30                           -0.016867          570.8       1280.08
# 2006-01-31                           -1.239087          569.4       1282.46
# 2006-02-01                           -1.129202          572.5       1270.84
#
#             Tomorrow Gold Return  Tomorrow S&P Return
# Date
# 2006-01-26             -0.001787             0.007764
# 2006-01-27              0.012708             0.001145
# 2006-01-30              0.008837            -0.003976
# 2006-01-31             -0.002453             0.001859
# 2006-02-01              0.005444            -0.009061
#
# [5 rows x 24 columns]

# %%
trainTableNew = table.loc[:"2017-12-26",:]
testTableNew  = table.loc["2017-12-27":,:]

# %%
kMeansTable = table[['Normalised Gold Return', 'Normalised Gold Return 2 day back 1', 'Normalised Gold Return 4 day back 3', 'Normalised Gold Return 8 day back 7', 'Var 16 day', 'Normalised S&P Return', 'Normalised S&P Return 2 day back 1', 'Normalised S&P Return 4 day back 3', 'Normalised S&P Return 8 day back 7', 'Var 16 day.1']]
trainKMeansTableNew = kMeansTable.iloc[:3000,:]
testKMeansTableNew = kMeansTable.iloc[3000:,:]

# %%
trainKMeansTableNew.shape
# Out:
# (3000, 10)

# %%
testKMeansTableNew.shape
# Out:
# (992, 10)

# %%
num_clusters = 6
from sagemaker import KMeans

kmeans = KMeans(
    role=role,
    instance_count=1,
    instance_type="ml.c4.xlarge",
    output_path="s3://" + s3Bucket + "/groups/",
    k=num_clusters,
)

# %%
kmeans.fit(kmeans.record_set(trainKMeansTableNew.values.astype("float32")))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-12-23 00:28:37 Starting - Starting the training job...
# 2021-12-23 00:29:01 Starting - Launching requested ML instancesProfilerReport-1640219317: InProgress
# ......
# 2021-12-23 00:30:01 Starting - Preparing the instances for training............
# 2021-12-23 00:32:02 Downloading - Downloading input data...
# 2021-12-23 00:32:39 Training - Training image download completed. Training in progress.
# 2021-12-23 00:32:39 Uploading - Uploading generated training model.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/23/2021 00:32:37 INFO 140020496934720] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [12/23/2021 00:32:37 INFO 140020496934720] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '10', 'k': '6', 'force_dense': 'True'}
# [12/23/2021 00:32:37 INFO 140020496934720] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '10', 'k': '6'}
# [12/23/2021 00:32:37 WARNING 140020496934720] Loggers have already been setup.
# Process 1 is a worker.
# [12/23/2021 00:32:37 INFO 140020496934720] Using default worker.
# [12/23/2021 00:32:37 INFO 140020496934720] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [12/23/2021 00:32:37 INFO 140020496934720] Create Store: local
# [12/23/2021 00:32:37 INFO 140020496934720] nvidia-smi: took 0.031 seconds to run.
# [12/23/2021 00:32:37 INFO 140020496934720] nvidia-smi identified 0 GPUs.
# [12/23/2021 00:32:37 INFO 140020496934720] Number of GPUs being used: 0
# [12/23/2021 00:32:37 INFO 140020496934720] Checkpoint loading and saving are disabled.
# [12/23/2021 00:32:37 INFO 140020496934720] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '10', 'k': '6'}
# [12/23/2021 00:32:37 INFO 140020496934720] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [12/23/2021 00:32:37 INFO 140020496934720] Number of GPUs being used: 0
# [12/23/2021 00:32:37 INFO 140020496934720] number of center slices 1
# [12/23/2021 00:32:37 WARNING 140020496934720] Batch size 5000 is bigger than the first batch data. Effective batch size used to initialize is 3000
# #metrics {"StartTime": 1640219557.2988107, "EndTime": 1640219557.2988412, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3000.0, "count": 1, "min": 3000, "max": 3000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 3000.0, "count": 1, "min": 3000, "max": 3000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 3000.0, "count": 1, "min": 3000, "max": 3000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [2021-12-23 00:32:37.299] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 32, "num_examples": 1, "num_bytes": 192000}
# [2021-12-23 00:32:37.355] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 52, "num_examples": 1, "num_bytes": 192000}
# [12/23/2021 00:32:37 INFO 140020496934720] processed a total of 3000 examples
# [12/23/2021 00:32:37 INFO 140020496934720] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1640219557.2991736, "EndTime": 1640219557.3558757, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 6000.0, "count": 1, "min": 6000, "max": 6000}, "Total Batches Seen": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Max Records Seen Between Resets": {"sum": 3000.0, "count": 1, "min": 3000, "max": 3000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 3000.0, "count": 1, "min": 3000, "max": 3000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/23/2021 00:32:37 INFO 140020496934720] #throughput_metric: host=algo-1, train throughput=52777.1290517415 records/second
# [12/23/2021 00:32:37 WARNING 140020496934720] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/23/2021 00:32:37 INFO 140020496934720] shrinking 60 centers into 6
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #0. Current mean square distance 2.817995
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #1. Current mean square distance 2.820473
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #2. Current mean square distance 2.804299
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #3. Current mean square distance 2.799676
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #4. Current mean square distance 2.846777
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #5. Current mean square distance 2.715446
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #6. Current mean square distance 2.767675
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #7. Current mean square distance 2.737656
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #8. Current mean square distance 2.704036
# [12/23/2021 00:32:37 INFO 140020496934720] local kmeans attempt #9. Current mean square distance 2.767030
# [12/23/2021 00:32:37 INFO 140020496934720] finished shrinking process. Mean Square Distance = 3
# [12/23/2021 00:32:37 INFO 140020496934720] #quality_metric: host=algo-1, train msd <loss>=2.704035520553589
# [12/23/2021 00:32:37 INFO 140020496934720] compute all data-center distances: inner product took: 31.7749%, (0.019916 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] collect from kv store took: 11.1992%, (0.007020 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] gradient: cluster center took: 11.1962%, (0.007018 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] batch data loading with context took: 11.1711%, (0.007002 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] splitting centers key-value pair took: 11.0585%, (0.006931 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] compute all data-center distances: point norm took: 6.7168%, (0.004210 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] gradient: one_hot took: 6.5970%, (0.004135 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] predict compute msd took: 4.9408%, (0.003097 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] update state and report convergance took: 3.1868%, (0.001997 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] gradient: cluster size  took: 1.5147%, (0.000949 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] update set-up time took: 0.3652%, (0.000229 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] compute all data-center distances: center norm took: 0.2465%, (0.000154 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] predict minus dist took: 0.0323%, (0.000020 secs)
# [12/23/2021 00:32:37 INFO 140020496934720] TOTAL took: 0.06267857551574707
# [12/23/2021 00:32:37 INFO 140020496934720] Number of GPUs being used: 0
# #metrics {"StartTime": 1640219557.2662961, "EndTime": 1640219557.6363711, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 25.362014770507812, "count": 1, "min": 25.362014770507812, "max": 25.362014770507812}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 56.49685859680176, "count": 1, "min": 56.49685859680176, "max": 56.49685859680176}, "_shrink.time": {"sum": 277.2252559661865, "count": 1, "min": 277.2252559661865, "max": 277.2252559661865}, "finalize.time": {"sum": 278.49459648132324, "count": 1, "min": 278.49459648132324, "max": 278.49459648132324}, "model.serialize.time": {"sum": 1.6460418701171875, "count": 1, "min": 1.6460418701171875, "max": 1.6460418701171875}}}
# [12/23/2021 00:32:37 INFO 140020496934720] Test data is not provided.
# #metrics {"StartTime": 1640219557.6364734, "EndTime": 1640219557.636796, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 14.175653457641602, "count": 1, "min": 14.175653457641602, "max": 14.175653457641602}, "totaltime": {"sum": 442.75546073913574, "count": 1, "min": 442.75546073913574, "max": 442.75546073913574}}}
#
# 2021-12-23 00:33:02 Completed - Training job completed
# Training seconds: 52
# Billable seconds: 52

# %%
kmeans_predictor = kmeans.deploy(initial_instance_count=1, instance_type="ml.t2.medium")
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ----------!

# %%
trainResult = kmeans_predictor.predict(trainKMeansTableNew.values.astype("float32"))

# %%
testResult = kmeans_predictor.predict(testKMeansTableNew.values.astype("float32"))

# %%
kmeans_predictor.delete_endpoint()

# %%
trainResultList = [int(i.label["closest_cluster"].float32_tensor.values[0]) for i in trainResult]
trainTableNew['Cluster'] = trainResultList
trainTableNew.head()
trainTableNew.to_csv("clusteredTrain.csv")
[trainTableNew[trainTableNew['Cluster']==i].to_csv("train" + str(i) + ".csv") for i in np.unique(trainTableNew['Cluster'].values.ravel())]
trainTableClustered = [trainTableNew[trainTableNew['Cluster']==i] for i in np.unique(trainTableNew['Cluster'].values.ravel())]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
testResultList = [int(i.label["closest_cluster"].float32_tensor.values[0]) for i in testResult]
testTableNew['Cluster'] = testResultList
testTableNew.head()
testTableNew.to_csv("clusteredTest.csv")
[testTableNew[testTableNew['Cluster']==i].to_csv("test" + str(i) + ".csv") for i in np.unique(testTableNew['Cluster'].values.ravel())]
testTableClustered = [testTableNew[testTableNew['Cluster']==i] for i in np.unique(testTableNew['Cluster'].values.ravel())]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
trainTableClustered[0].head()
# Out:
#             Gold Price      S&P  Gold Return  Gold Return 2 day back 1  \
# Date
# 2006-01-31       570.8  1280.08     0.008837                  0.010899
# 2006-02-15       539.7  1280.00    -0.011357                 -0.007815
# 2006-02-16       546.0  1289.38     0.011673                  0.001299
# 2006-02-17       551.8  1287.24     0.010623                  0.000183
# 2006-02-21       553.9  1283.03     0.003806                  0.022420
#
#             Gold Return 4 day back 3  Gold Return 8 day back 7  Var 16 day  \
# Date
# 2006-01-31                  0.011201                  0.008013    0.011519
# 2006-02-15                 -0.035075                  0.014230    0.015444
# 2006-02-16                 -0.021779                 -0.015544    0.015625
# 2006-02-17                 -0.007635                 -0.015393    0.015901
# 2006-02-21                 -0.043933                 -0.002298    0.015938
#
#             Normalised Gold Return  Normalised Gold Return 2 day back 1  \
# Date
# 2006-01-31                0.767178                             0.669035
# 2006-02-15               -0.735391                            -0.357827
# 2006-02-16                0.747086                             0.058773
# 2006-02-17                0.668065                             0.008146
# 2006-02-21                0.238779                             0.994665
#
#             Normalised Gold Return 4 day back 3  ...  Var 16 day.1  \
# Date                                             ...
# 2006-01-31                             0.486221  ...      0.006339
# 2006-02-15                            -1.135567  ...      0.005850
# 2006-02-16                            -0.696919  ...      0.006039
# 2006-02-17                            -0.240083  ...      0.005856
# 2006-02-21                            -1.378213  ...      0.005609
#
#             Normalised S&P Return  Normalised S&P Return 2 day back 1  \
# Date
# 2006-01-31              -0.627284                            0.994861
# 2006-02-15               0.599032                            0.814710
# 2006-02-16               1.213492                            1.589223
# 2006-02-17              -0.283444                            1.311229
# 2006-02-21              -0.583090                            0.713060
#
#             Normalised S&P Return 4 day back 3  \
# Date
# 2006-01-31                            0.771635
# 2006-02-15                            0.133098
# 2006-02-16                            0.533160
# 2006-02-17                            0.666573
# 2006-02-21                            1.144095
#
#             Normalised S&P Return 8 day back 7  Tomorrow Gold  Tomorrow S&P  \
# Date
# 2006-01-31                           -1.239087          569.4       1282.46
# 2006-02-15                            0.016248          546.0       1289.38
# 2006-02-16                           -0.875553          551.8       1287.24
# 2006-02-17                           -0.849919          553.9       1283.03
# 2006-02-21                           -1.050067          553.9       1292.67
#
#             Tomorrow Gold Return  Tomorrow S&P Return  Cluster
# Date
# 2006-01-31             -0.002453             0.001859        0
# 2006-02-15              0.011673             0.007328        0
# 2006-02-16              0.010623            -0.001660        0
# 2006-02-17              0.003806            -0.003271        0
# 2006-02-21              0.000000             0.007513        0
#
# [5 rows x 25 columns]

# %%
#
#model_key = "groups/" + kmeans.latest_training_job.name + "/output/model.tar.gz"
#boto3.resource("s3").Bucket(bucket).download_file(model_key, "model.tar.gz")
#os.system("tar -zxvf model.tar.gz")
#Kmeans_model_params = mx.ndarray.load("model_algo-1")
#cluster_centroids = pd.DataFrame(Kmeans_model_params[0].asnumpy())
#cluster_centroids.columns = counties_transformed.columns
#
